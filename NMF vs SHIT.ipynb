# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse import dok_matrix, csr_matrix #matrice "sparse"
import seaborn as sns
from Item2Vec import *

# Dataframe : line 'serie', column 'user', cell 'Rating/10 or NaN'
df = pd.read_csv('userratings.csv').drop('Unnamed: 0', axis='columns')
# Dataframe to convert between the different namings of series
#nameConvert = pd.read_csv('namesConvert.csv')
# Series titles ordered by the same order as in the ratings csv
titles = pd.read_csv('titles.csv')

# Loading the similarity matrix
simMat = np.load('similarity_matrices/sim_15_.npy')

# Keep.csv contains the lines/columns to keep from the similarity matrix
# keep only the ones that match the series we have in userratings.csv
keep = pd.read_csv('keep.csv')
keeps = keep['index'].values
simMat = simMat[keeps][:,keeps]
series = keep['seriesname'].values

sns.set(color_codes=True)
plt.style.use('seaborn-white')
# %matplotlib inline

#dataset path
path = "dataset"

tableSeries = "series.csv"

# %%
from Item2Vec import *

# %%
df2 = df*2
df2
# Out:
#      ToddTee  bkoganbing  betwana  fabiogaucho  killer1h  rasadi27  \
# 0        NaN         NaN      NaN          NaN       NaN       NaN
# 1        NaN         NaN      NaN          NaN       NaN       NaN
# 2        NaN        20.0      NaN          NaN       NaN       NaN
# 3        NaN         NaN      NaN          NaN       NaN       NaN
# 4        NaN        18.0      NaN          NaN       NaN       NaN
# 5        NaN        18.0      NaN          NaN       NaN       NaN
# 6        NaN        16.0      NaN          NaN       NaN       NaN
# 7        NaN        20.0      NaN          NaN       NaN       NaN
# 8        NaN         NaN      NaN          NaN       NaN       NaN
# 9        NaN        14.0      NaN          NaN       NaN       NaN
# 10       NaN         NaN      NaN          NaN       NaN       NaN
# 11       NaN         NaN      NaN          NaN       NaN       NaN
# 12       NaN         NaN      NaN          NaN       NaN       NaN
# ...

# %%
model = Item2Vec(df2, titles, simMat)

# %%
import time
start = time.time()

_ = model.train(vec_size = 100, window = 1000, sim = 3, iters = 100, min_count = 12, clustering = True, weighted = True)

end = time.time()
print(end - start, "TIIIME")
# Out:
# MSE , Zero predictions
# 6.8580958844324815 17
# count    1423.000000
# mean        2.397751
# std         1.671485
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        15.000000
# dtype: float64
# Prediction percentage
# count    1423.000000
# mean        0.358515
# std         0.192859
# min         0.000000
# 25%         0.222222
# 50%         0.300000
# 75%         0.500000
# max         1.000000
# dtype: float64
# 23.68563747406006 TIIIME

# %%
seriesnmf = pd.read_csv(tableSeries)
seriesnmf = seriesnmf[["seriesname", "imdbId"]]

# %%
filename = "userratings.csv"
dfnmf = pd.read_csv(filename)

# %%
serieX = ['The Mentalist', 'NCIS: Los Angeles', 'Criminal Minds', 'Hawaii Five-0', 'Rick and Morty', 'The Simpsons', 'How I Met Your Mother', 'Friends', 'Batman', 'Smallville', 'Game of Thrones']
notesX = [18, 17, 18, 18, 2, 2, 5, 6, 19, 16,11]
r = []

for serie in serieX:
    r.append( np.where( titles.values.ravel() == serie)[0][0])  
    print( (serie , np.where( titles.values.ravel() == serie)[0][0]) )
print(r)
x = pd.DataFrame([notesX],columns=r)
x = x.rename(index={0: 'ismael'})
# Out:
# ('The Mentalist', 515)
# ('NCIS: Los Angeles', 551)
# ('Criminal Minds', 365)
# ('Hawaii Five-0', 633)
# ('Rick and Morty', 857)
# ('The Simpsons', 113)
# ('How I Met Your Mother', 377)
# ('Friends', 156)
# ('Batman', 0)
# ('Smallville', 268)
# ('Game of Thrones', 465)
# [515, 551, 365, 633, 857, 113, 377, 156, 0, 268, 465]

# %%
dfnmf.rename(columns={"Unnamed: 0":'item'}, inplace=True)
dfnmf = pd.concat([dfnmf, x.T], axis=1, sort=False)
dfnmf = dfnmf.loc[:, (dfnmf.count(axis=0) >= 4)]
dfnmf = dfnmf.loc[(dfnmf.count(axis=1) >= 4), :]

# %%
df2['ismael'] = np.NaN
serieX = ['The Mentalist', 'NCIS: Los Angeles', 'Criminal Minds', 'Hawaii Five-0', 'Rick and Morty', 'The Simpsons', 'How I Met Your Mother', 'Friends', 'Batman', 'Smallville', 'Game of Thrones']
notesX = [18, 17, 18, 18, 2, 2, 5, 6, 19, 16,11]
model = Item2Vec(df2, titles, simMat)
for i in range(len(serieX)):
    model.rate('ismael',serieX[i],notesX[i])
df2
# Out:
# Before
# ismael   NaN
# Name: 515, dtype: float64
# After
# ismael    18.0
# Name: 515, dtype: float64
# Before
# ismael   NaN
# Name: 551, dtype: float64
# After
# ismael    17.0
# Name: 551, dtype: float64
# Before
# ismael   NaN
# Name: 365, dtype: float64
# After
# ismael    18.0
# Name: 365, dtype: float64
# Before
# ismael   NaN
# Name: 633, dtype: float64
# After
# ismael    18.0
# Name: 633, dtype: float64
# Before
# ismael   NaN
# Name: 857, dtype: float64
# After
# ismael    2.0
# Name: 857, dtype: float64
# Before
# ismael   NaN
# Name: 113, dtype: float64
# After
# ismael    2.0
# Name: 113, dtype: float64
# Before
# ismael   NaN
# Name: 377, dtype: float64
# After
# ismael    5.0
# Name: 377, dtype: float64
# Before
# ismael   NaN
# Name: 156, dtype: float64
# After
# ismael    6.0
# Name: 156, dtype: float64
# Before
# ismael   NaN
# Name: 0, dtype: float64
# After
# ismael    19.0
# Name: 0, dtype: float64
# Before
# ismael   NaN
# Name: 268, dtype: float64
# After
# ...

# %%
serie_dict = []
for imdbId in dfnmf["item"]:
    if len(list(seriesnmf[seriesnmf["imdbId"] == imdbId]["seriesname"])) != 0:
        serie_dict.append(list(seriesnmf[seriesnmf["imdbId"] == imdbId]["seriesname"])[0])
    else:
        serie_dict.append('NotFound')

# %%
dfnmf = dfnmf.drop(columns=['item']) #enlever la colonne des noms de série
dfnmf = dfnmf.transpose()

# %%
dfnmf.columns = list(range(len(serie_dict)))

# %%
train = dfnmf.notnull().values

# %%
import random

test_size = 0.2
test = train.copy()

for i in range(dfnmf.shape[0]):
    for j in range(dfnmf.shape[1]):
        if train[i,j]:
            if random.random() < test_size:
                #ajouter dans test et enlever de train
                train[i,j] = False
            else:
                test[i,j] = False

# %%
import tensorflow as tf

# %%
import time

start = time.time()



#moyenne item
baseline = tf.constant(np.tile(np.array(dfnmf.mean(axis=0)),(len(dfnmf),1)) / 10.)

#latent factors
k = 100
shape = dfnmf.shape

#constante: la matrice R à reconstituer entièrement
R = tf.constant(dfnmf.values / 10) #divisée par 10 pour obtenir des notes entre 0 et 1

#variable tensorflow masque
mask_tf_train = tf.Variable(train)
mask_tf_test = tf.Variable(test)

#variables tensorflow
#U et I initialisés selon une loi normale et normalisés en divisant par k
U = tf.Variable(np.abs(np.random.normal(scale=1./k, size=(shape[0], k)).astype(np.float64)), name="U")
I = tf.Variable(np.abs(np.random.normal(scale=1./k, size=(k, shape[1])).astype(np.float64)), name="I")

R_pred = tf.matmul(U, I) #embeddings

#beta: paramètre de regularization
beta = tf.constant(0.0001, dtype=tf.float64, name="beta")
regularizer = beta * (tf.reduce_sum(tf.square(U)) + tf.reduce_sum(tf.square(I)))

#cout de l'algo NMF, norme matricielle de R - R_pred
cost = tf.reduce_sum(tf.square(tf.boolean_mask(R, mask_tf_train) - tf.boolean_mask(R_pred, mask_tf_train)))
cost += regularizer

#contraintes de non-négativité de U et I
clip_U = U.assign(tf.maximum(tf.zeros_like(U), U))
clip_I = I.assign(tf.maximum(tf.zeros_like(I), I))
clip = tf.group(clip_U, clip_I)

#erreur MSE train
mse_train = tf.reduce_mean(tf.square(tf.boolean_mask(R_pred, mask_tf_train) - tf.boolean_mask(R, mask_tf_train)), name="mse_train")
mse_test = tf.reduce_mean(tf.square(tf.boolean_mask(R_pred, mask_tf_test) - tf.boolean_mask(R, mask_tf_test)), name="mse_test")

#baseline MSE test
baselineMSE = tf.reduce_mean(tf.square(tf.boolean_mask(baseline, mask_tf_test) - tf.boolean_mask(R, mask_tf_test)))

alpha = 0.001 #learning rate
global_step = tf.Variable(0, trainable=False)

optimizer = tf.train.AdamOptimizer(alpha).minimize(cost, global_step=global_step)

steps = 1000
costs = []
mses_train = []
mses_test = []

sess = tf.Session()
sess.run(tf.initialize_all_variables())
for i in range(steps):
    sess.run(optimizer)
    sess.run(clip)
    if i%100==0:
        cst = sess.run(cost)
        msetrain = sess.run(mse_train)
        msetest = sess.run(mse_test)
        costs.append((i, cst))
        mses_train.append((i, msetrain))
        mses_test.append((i, msetest))
        
            
learnt_U = sess.run(U)
learnt_I = sess.run(I)
msebaseline = sess.run(baselineMSE)
sess.close()

end = time.time()
print(end - start, " TIIIIMEE")
# Out:
# WARNING:tensorflow:From /root/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /root/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /root/anaconda3/lib/python3.7/site-packages/tensorflow/python/util/tf_should_use.py:193: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# 22.89080834388733  TIIIIMEE

# %%
def score(serieFrom, serieTo, cleanName = False, verbose = False):
    if cleanName:
        serieAidx = titles.title[titles.title == serieFrom].index[0]
        serieBidx = titles.title[titles.title == serieTo].index[0]
        serieAname = namesConvert.iloc[serieAidx].seriesname
        serieBname = namesConvert.iloc[serieBidx].seriesname
    else:
        serieAname = serieFrom
        serieBname = serieTo
    genresA = series_df[series_df.seriesname == serieAname].genres.values[0]
    genresB = series_df[series_df.seriesname == serieBname].genres.values[0]
    c = 0
    f = 0
    common = []
    genresAsplitted = genresA.split('-')
    for genrea in genresAsplitted:
        if bool(genresB.find(genrea)+1):
            c += 1
            common.append(genrea)
    if bool(genresA.find('Science')+1):
        c -= 1
        f = 1
    l = len(genresAsplitted)
    if verbose:
        print(serieFrom, " => ", genresA)
        print(serieTo, " => ", genresB)
        print("Intersect", " => ",common)
        print(c, '/', l-f )
    return c/(l-f)

# %%
len(dfnmf)
# Out:
# 1424

# %%
xptdr = np.clip(np.round(np.dot(learnt_U, learnt_I) * 20), a_min=0, a_max=20)

user = 1423
userName = dfnmf.iloc[user].name
print(dfnmf.iloc[user].name)
lol = [(i,a) for i, a in enumerate(dfnmf.iloc[user].values) if not np.isnan(a)]
lol.sort(key=lambda x: x[1])
print("notes observées: (toutes)\n")
for i, rating in lol[::-1]:
    print(rating,"\t"," ".join(serie_dict[i].split("_")[1:]))
    
hhhh = [a for a,b in lol]
mdr = [a for a in np.argsort(xptdr[user])[::-1] if a not in hhhh]
print("\nséries recommandées: (top 7)\n")
for i in mdr[:10]:
    print(xptdr[user][i],"\t", " ".join(serie_dict[i].split("_")[1:]))
# Out:
# ismael
# notes observées: (toutes)
#
# 19.0 	 The Batman
# 18.0 	 Hawaii Five-0 (2010)
# 18.0 	 The Mentalist
# 18.0 	 Criminal Minds
# 17.0 	 NCIS Los Angeles
# 16.0 	 Smallville
# 11.0 	 Game of Thrones
# 6.0 	 Friends
# 5.0 	 How I Met Your Mother
# 2.0 	 Rick and Morty
# 2.0 	 The Simpsons
#
# séries recommandées: (top 7)
#
# 20.0 	 Z Nation
# 20.0 	 Deadwood
# 20.0 	 Teen Titans
# 20.0 	 Wire In The Blood
# 20.0 	 The L Word
# 20.0 	 John Doe
# 20.0 	 Carnivale
# 20.0 	 Everwood
# 20.0 	 Odyssey 5
# 20.0 	 Monk

# %%
sim = np.load("sim_725_embeddings.npy") #matrice de similarités item sauvegardée au format numpy

# %%
xptdr.T.shape, sim.shape
# Out:
# ((726, 1424), (725, 725))

# %%
serieA = '396_Batman'
serieB = '3092_The_Mighty_Boosh'
score(serieA, serieB, cleanName = False, verbose = True)
# Out:
# 396_Batman  =>  Action-Adventure-Fantasy
# 3092_The_Mighty_Boosh  =>  Comedy
# Intersect  =>  []
# 0 / 3
# 0.0

# %%
import pandas as pd 

series_df = pd.read_csv("series.csv")
series_df = series_df.dropna(subset=["genres"])
series = list(series_df["seriesname"])

# %%
df2['ismael'] = np.NaN
serieX = ['The Mentalist', 'NCIS: Los Angeles', 'Criminal Minds', 'Hawaii Five-0', 'Rick and Morty', 'The Simpsons', 'How I Met Your Mother', 'Friends', 'Batman', 'Smallville', 'Game of Thrones']
notesX = [18, 17, 18, 18, 2, 2, 5, 6, 19, 16,11]
model = Item2Vec(df2, titles, simMat)
for i in range(len(serieX)):
    model.rate('ismael',serieX[i],notesX[i])
df2
# Out:
# Before
# ismael   NaN
# Name: 515, dtype: float64
# After
# ismael    18.0
# Name: 515, dtype: float64
# Before
# ismael   NaN
# Name: 551, dtype: float64
# After
# ismael    17.0
# Name: 551, dtype: float64
# Before
# ismael   NaN
# Name: 365, dtype: float64
# After
# ismael    18.0
# Name: 365, dtype: float64
# Before
# ismael   NaN
# Name: 633, dtype: float64
# After
# ismael    18.0
# Name: 633, dtype: float64
# Before
# ismael   NaN
# Name: 857, dtype: float64
# After
# ismael    2.0
# Name: 857, dtype: float64
# Before
# ismael   NaN
# Name: 113, dtype: float64
# After
# ismael    2.0
# Name: 113, dtype: float64
# Before
# ismael   NaN
# Name: 377, dtype: float64
# After
# ismael    5.0
# Name: 377, dtype: float64
# Before
# ismael   NaN
# Name: 156, dtype: float64
# After
# ismael    6.0
# Name: 156, dtype: float64
# Before
# ismael   NaN
# Name: 0, dtype: float64
# After
# ismael    19.0
# Name: 0, dtype: float64
# Before
# ismael   NaN
# Name: 268, dtype: float64
# After
# ...

# %%
import time
start = time.time()

_ = model.train(vec_size = 100, window = 1000, sim = 3, iters = 100, min_count = 12, clustering = True, weighted = True)

end = time.time()
print(end - start, "TIIIME")
# Out:
# MSE , Zero predictions
# 6.629111247356969 15
# count    1424.000000
# mean        2.411517
# std         1.693452
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        16.000000
# dtype: float64
# Prediction percentage
# count    1424.000000
# mean        0.359558
# std         0.189242
# min         0.000000
# 25%         0.234163
# 50%         0.300000
# 75%         0.500000
# max         1.000000
# dtype: float64
# 26.228981018066406 TIIIME

# %%
model.recommend('ismael',7,similOdds = 0.0, weighted = True, minNbRates = 500)[:10]
# Out:
#      Predicted                 title
# 277  20.000000            The Shield
# 334  20.000000               CSI: NY
# 810  20.000000        Crossing Lines
# 379  20.000000          Supernatural
# 712  20.000000    Person of Interest
# 50   18.000000  Black Sheep Squadron
# 582  18.000000           Strike Back
# 855  18.000000          Chicago P.D.
# 751  18.000000         The Following
# 313  16.291501                  NCIS

# %%
model.showUserOriginal('ismael')
# Out:
#                      title  rate
# 0                   Batman  19.0
# 113           The Simpsons   2.0
# 156                Friends   6.0
# 268             Smallville  16.0
# 365         Criminal Minds  18.0
# 377  How I Met Your Mother   5.0
# 465        Game of Thrones  11.0
# 515          The Mentalist  18.0
# 551      NCIS: Los Angeles  17.0
# 633          Hawaii Five-0  18.0
# 857         Rick and Morty   2.0

# %%
model.predictUser('ismael', dropnan = True, weighted = False, showTitle = True)
# Out:
#                  Title  Predicted  Original
# 365     Criminal Minds       18.0      18.0
# 515      The Mentalist       10.0      18.0
# 551  NCIS: Los Angeles       17.0      17.0
# 633      Hawaii Five-0       18.0      18.0
